# %% [markdown]
# # Import

# %%
# Import Libraries
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)  # Adjusts the configuration of the plots we will create

# %%
# Import Data

df = pd.read_csv("movies.csv")

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.shape
# Out:
# (7668, 15)

# %%
df.isna().value_counts()
# Out:
# name   rating  genre  year   released  score  votes  director  writer  star   country  budget  gross  company  runtime
# False  False   False  False  False     False  False  False     False   False  False    False   False  False    False      5421
#                                                                                        True    False  False    False      1991
#                                                                                                True   False    False       110
#                                                                                        False   True   False    False        52
#        True    False  False  False     False  False  False     False   False  False    True    False  False    False        41
#                                                                                                True   False    False        15
# ...

# %%
df.count()  # Drop 2247 records due to dropping NA
# Out:
# name        7668
# rating      7591
# genre       7668
# year        7668
# released    7666
# score       7665
# votes       7665
# director    7668
# writer      7665
# star        7667
# country     7665
# budget      5497
# gross       7479
# company     7651
# runtime     7664
# dtype: int64

# %%
# How many records have a null value
df.isna().any(axis=1).sum()
# Out:
# 2247

# %% [markdown]
# # Data Cleaning

# %%
# Loop through columns to find any missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())  # Loop through col and see if there are any nulls
    print('{} - {}%'.format(col, pct_missing))  # Formatting to add a % at the end of the column value
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
# Drop NA records
df.dropna(inplace=True)

# %%
# Review data types of our columns
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
# Convert budget and gross from float to int
df["budget"] = df["budget"].astype("int64")
df["gross"] = df["gross"].astype("int64")

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %% [markdown]
# Data cleaning: take the 'year' value from the "released" column and put it into a new column

# %%
df[df["released"].str.match(".*(United States)*.") == True].value_counts(["released"], ascending=False)
# Out:
# released
# October 11, 2002 (United States)     7
# August 26, 2016 (United States)      7
# December 16, 1983 (United States)    7
# December 25, 2008 (United States)    7
# January 25, 2002 (United States)     7
#                                     ..
# July 31, 1991 (United States)        1
# July 30, 1997 (United States)        1
# July 30, 1982 (United States)        1
# July 3, 2019 (United States)         1
# September 9, 2016 (United States)    1
# Length: 2560, dtype: int64

# %%
# pd.set_option('display.max_rows', 500)
# pd.reset_option('all')
# df["released"].astype(str).str[-20:-15].value_counts()
# df["released_year"] = parser.parse(str(df["released"][:len(df["released"])]))

df["year_correct"] = df["released"].astype(str).str.split(', ').str[-1].astype(str).str[:4]

# %%
df
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       137    8.4   903000.0       105     513
# 3045  4909       5      6  1997       534    7.8  1100000.0       785    1263
# 6663  3643       5      0  2015       529    7.8   876000.0       768    1806
# 7244   389       5      0  2018       145    8.4   897000.0       105     513
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 5640  3794       6      6  2009       890    5.8     3500.0       585    2924
# 2434  2969       5      0  1993      1467    4.5     1900.0      1805    3102
# 3681  1595       3      6  2000      1721    6.8    43000.0       952    1683
# 272   2909       6      9  1982      1525    3.9     2300.0       261      55
# 3203  4966       5      4  1997      2152    5.7     5800.0       651     161
#
# ...

# %%
# order by gross revenue

df = df.sort_values(by=["gross"], inplace=False, ascending=False)

# %%
# pd.set_option('display.max_rows', None) # look at all the data
pd.set_option('display.max_rows', 500)

# %%
# Drop duplicates
df["company"].drop_duplicates().sort_values(ascending=False)  # shows what values are distinct
# Out:
# 7129                                thefyzz
# 5664                            micro_scope
# 4007                               i5 Films
# 6793                             i am OTHER
# 6420                                   erbp
#                        ...
# 385                        1818 Productions
# 2929                          1492 Pictures
# 3024                        .406 Production
# 7525    "Weathering With You" Film Partners
# 4345        "DIA" Productions GmbH & Co. KG
# Name: company, Length: 1475, dtype: object

# %%
# df.drop_duplicates()  # dropping duplicates in entire dataframe

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %% [markdown]
# Hypothesis:
# - Budget will have high correlation gross
# - Company may have a high correlation to gross

# %%
# Scatter plot with budget vs gross revenue

plt.scatter(x=df["budget"], y=df["gross"])
plt.title("Budget vs. Gross Earnings")
plt.xlabel("Budget for Film")
plt.ylabel("Gross Earnings")

plt.show()

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %% [markdown]
# Regplot - Regression plot

# %%
sns.regplot(x="budget", y="gross", data=df, scatter_kws={"color": "red"}, line_kws={"color": "black"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %% [markdown]
# What is the actual correlation

# %%
# This only works on numerical fields
# By Default, this is the Pearson correlation; other correlation methods: kendall, spearman
# df.corr()
df.corr(method="pearson")
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %% [markdown]
# Budget and Gross have a high corelation at 0.740247
#
# Votes and Gross is also high at 0.614751

# %%
# Using heatmap to better see the correlations
correlation_matrix = df.corr(method="pearson")

sns.heatmap(correlation_matrix, annot=True)
plt.title("Correlation Matrix for Numeric Features")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")

plt.show()

# %% [markdown]
# Look at Company
# - Not numeric
# - Create a numeric representation; i.e. assign ID per company so that it can be included in correlation matrix

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
df_company_id = df

for col_name in df_company_id.columns:
    if(df_company_id[col_name].dtype == "object"):
        df_company_id[col_name] = df_company_id[col_name].astype("category")  # change object type to category
        df_company_id[col_name] = df_company_id[col_name].cat.codes  # cat codes; gives random number/id

# %% [markdown]
# Anything that was numeric, was left alone

# %%
df_company_id
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       137    8.4   903000.0       105     513
# 3045  4909       5      6  1997       534    7.8  1100000.0       785    1263
# 6663  3643       5      0  2015       529    7.8   876000.0       768    1806
# 7244   389       5      0  2018       145    8.4   897000.0       105     513
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 5640  3794       6      6  2009       890    5.8     3500.0       585    2924
# 2434  2969       5      0  1993      1467    4.5     1900.0      1805    3102
# 3681  1595       3      6  2000      1721    6.8    43000.0       952    1683
# 272   2909       6      9  1982      1525    3.9     2300.0       261      55
# 3203  4966       5      4  1997      2152    5.7     5800.0       651     161
#
# ...

# %%
df
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
# Using heatmap to better see the correlations
correlation_matrix = df_company_id.corr(method="pearson")

sns.heatmap(correlation_matrix, annot=True)
plt.title("Correlation Matrix for Numeric Features")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")

plt.show()

# %% [markdown]
# Correlation observations
# - Company does not have much of a correlation with gross revenue: 0.15
# - Rating and Genre had a negative correlation to gross revenue: -0.18/0.24
# - Budget has a high correlation to gross revenue: 0.74
# - Votes have a high correlation: 0.61

# %%
df_company_id.corr()
# Out:
#                   name    rating     genre      year  released     score  \
# name          1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating       -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre         0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year          0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released     -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score         0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes         0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director      0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer        0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star         -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country      -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget        0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# ...

# %% [markdown]
# Unstacking

# %%
correlation_mat = df_company_id.corr()
corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name          name            1.000000
#               rating         -0.029234
#               genre           0.010996
#               year            0.025542
#               released       -0.006152
#               score           0.014450
#               votes           0.012615
#               director        0.015246
#               writer          0.012880
#               star           -0.006882
#               country        -0.025490
#               budget          0.023392
#               gross           0.005639
#               company         0.021697
#               runtime         0.010850
#               year_correct    0.023234
# rating        name           -0.029234
#               rating          1.000000
#               genre           0.147796
#               year            0.019499
#               released        0.018083
#               score           0.065983
#               votes           0.006031
#               director        0.014656
# ...

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre         budget         -0.368523
# budget        genre          -0.368523
# gross         genre          -0.244101
# genre         gross          -0.244101
# rating        budget         -0.203946
# budget        rating         -0.203946
# rating        gross          -0.181906
# gross         rating         -0.181906
# votes         genre          -0.135990
# genre         votes          -0.135990
# company       rating         -0.092357
# rating        company        -0.092357
# country       year_correct   -0.074422
# year_correct  country        -0.074422
# year          genre          -0.073167
# genre         year           -0.073167
#               company        -0.071334
# company       genre          -0.071334
# year          country        -0.066748
# country       year           -0.066748
# genre         year_correct   -0.064308
# year_correct  genre          -0.064308
# genre         runtime        -0.059237
# runtime       genre          -0.059237
# ...

# %% [markdown]
# Look at only high correlated pairs (> 0.5 )

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# votes         gross           0.614751
# gross         votes           0.614751
# budget        gross           0.740247
# gross         budget          0.740247
# year_correct  year            0.990417
# year          year_correct    0.990417
# name          name            1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# year_correct  year_correct    1.000000
# dtype: float64

# %% [markdown]
# Conclusion:
# - Votes and Budget have highest correlation to Gross Earnings
# - Company has low correlation
